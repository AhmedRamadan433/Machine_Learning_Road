# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/ramen-ratings.csv')
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# ### Normal Selection

# %% [markdown]
# **Select Country Columns From data**

# %%
df['Country']
df.Country
# Out:
# 0          Japan
# 1         Taiwan
# 2            USA
# 3         Taiwan
# 4          India
#           ...
# 2575     Vietnam
# 2576    Thailand
# 2577    Thailand
# 2578    Thailand
# 2579         USA
# Name: Country, Length: 2580, dtype: object

# %% [markdown]
# ### Index Based Selection

# %%
#df.iloc[row,column]
df.iloc[0:4,:]
# Out:
#    Review #      Brand                                            Variety  \
# 0      2580  New Touch                          T's Restaurant Tantanmen
# 1      2579   Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2      2578     Nissin                      Cup Noodles Chicken Vegetable
# 3      2577    Wei Lih                      GGE Ramen Snack Tomato Flavor
#
#   Style Country Stars Top Ten
# 0   Cup   Japan  3.75     NaN
# 1  Pack  Taiwan     1     NaN
# 2   Cup     USA  2.25     NaN
# 3  Pack  Taiwan  2.75     NaN

# %%
df.iloc[:,-1]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2575    NaN
# 2576    NaN
# 2577    NaN
# 2578    NaN
# 2579    NaN
# Name: Top Ten, Length: 2580, dtype: object

# %% [markdown]
# > Fancy Indexing

# %%
df.iloc[[0,5,7],[1,-1]]
# Out:
#            Brand Top Ten
# 0      New Touch     NaN
# 5  Samyang Foods     NaN
# 7    Ikeda Shoku     NaN

# %%
df.iloc[-10:,:]
# Out:
#       Review #     Brand                                            Variety  \
# 2570        10     Smack                                     Vegetable Beef
# 2571         9     Sutah                                         Cup Noodle
# 2572         8    Tung-I                   Chinese Beef Instant Rice Noodle
# 2573         7   Ve Wong                                      Mushroom Pork
# 2574         6     Vifon                                           Nam Vang
# 2575         5     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2576         4   Wai Wai                     Oriental Style Instant Noodles
# 2577         3   Wai Wai                                     Tom Yum Shrimp
# 2578         2   Wai Wai                               Tom Yum Chili Flavor
# 2579         1  Westbrae                                         Miso Ramen
#
#      Style      Country Stars Top Ten
# 2570  Pack          USA   1.5     NaN
# 2571   Cup  South Korea     2     NaN
# ...

# %% [markdown]
# > Diff Between loc and iloc

# %%
 #iloc is Position-based indexing
 df.iloc[0:4,:]  #-->data from 0 to 3
# Out:
#    Review #      Brand                                            Variety  \
# 0      2580  New Touch                          T's Restaurant Tantanmen
# 1      2579   Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2      2578     Nissin                      Cup Noodles Chicken Vegetable
# 3      2577    Wei Lih                      GGE Ramen Snack Tomato Flavor
#
#   Style Country Stars Top Ten
# 0   Cup   Japan  3.75     NaN
# 1  Pack  Taiwan     1     NaN
# 2   Cup     USA  2.25     NaN
# 3  Pack  Taiwan  2.75     NaN

# %%
#loc is Label-based indexing
df.loc[0:4,:]  #-->data from 0 to 4
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# > Change indexing depend to Column

# %%
d1=df.set_index('Review #') #--> index to review colummn
d1.head(4)
# Out:
#               Brand                                            Variety Style  \
# Review #
# 2580      New Touch                          T's Restaurant Tantanmen    Cup
# 2579       Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2578         Nissin                      Cup Noodles Chicken Vegetable   Cup
# 2577        Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
#
#          Country Stars Top Ten
# Review #
# 2580       Japan  3.75     NaN
# 2579      Taiwan     1     NaN
# 2578         USA  2.25     NaN
# 2577      Taiwan  2.75     NaN

# %%
d1.iloc[0:4,:]
# Out:
#               Brand                                            Variety Style  \
# Review #
# 2580      New Touch                          T's Restaurant Tantanmen    Cup
# 2579       Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2578         Nissin                      Cup Noodles Chicken Vegetable   Cup
# 2577        Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
#
#          Country Stars Top Ten
# Review #
# 2580       Japan  3.75     NaN
# 2579      Taiwan     1     NaN
# 2578         USA  2.25     NaN
# 2577      Taiwan  2.75     NaN

# %%
test_df = df.set_index('Stars') # ----> Stars columns Removed from columns and converted to index
test_df.head()
test_df.columns
# Out:
# Index(['Review #', 'Brand', 'Variety', 'Style', 'Country', 'Top Ten'], dtype='object')

# %%
test_df.index = pd.to_numeric(test_df.index, errors='coerce')
test_df
# Out:
#        Review #           Brand  \
# Stars
# 3.75       2580       New Touch
# 1.00       2579        Just Way
# 2.25       2578          Nissin
# 2.75       2577         Wei Lih
# 3.75       2576  Ching's Secret
# ...         ...             ...
# 3.50          5           Vifon
# 1.00          4         Wai Wai
# 2.00          3         Wai Wai
# 2.00          2         Wai Wai
# 0.50          1        Westbrae
#
#                                                  Variety Style   Country  \
# Stars
# 3.75                           T's Restaurant Tantanmen    Cup     Japan
# 1.00   Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2.25                       Cup Noodles Chicken Vegetable   Cup       USA
# 2.75                       GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 3.75                                     Singapore Curry  Pack     India
# ...                                                  ...   ...       ...
# ...

# %% [markdown]
# ### Conditional Selection

# %%
df.Country =='Taiwan'
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 2575    False
# 2576    False
# 2577    False
# 2578    False
# 2579    False
# Name: Country, Length: 2580, dtype: bool

# %%
df.loc[df.Country =='Taiwan',:]
# Out:
#       Review #             Brand  \
# 1         2579          Just Way
# 3         2577           Wei Lih
# 40        2540           Wei Lih
# 65        2515     Uni-President
# 68        2512  Mom's Dry Noodle
# ...        ...               ...
# 2500        80     Unif / Tung-I
# 2512        68           Wei Lih
# 2522        58           Ve Wong
# 2537        43       Kim Ve Wong
# 2572         8            Tung-I
#
#                                                 Variety Style Country Stars  \
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 3                         GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 40        GGE Noodle Snack Wheat Crackers Mexican Spicy  Pack  Taiwan  3.25
# 65      Man Han Feast Spicy Beef Flavor Instant Noodles  Bowl  Taiwan     5
# 68                                       Dan Dan Noodle  Pack  Taiwan     5
# ...                                                 ...   ...     ...   ...
# ...

# %% [markdown]
# >Data has rating Above Avarage

# %%
st_col = pd.to_numeric(df.Stars, errors='coerce')
(df.loc[st_col> 2.5])
# Out:
#       Review #            Brand  \
# 0         2580        New Touch
# 3         2577          Wei Lih
# 4         2576   Ching's Secret
# 5         2575    Samyang Foods
# 6         2574          Acecook
# ...        ...              ...
# 2564        16          Samyang
# 2566        14          Samyang
# 2567        13  Sapporo Ichiban
# 2572         8           Tung-I
# 2575         5            Vifon
#
#                                                 Variety Style      Country  \
# 0                             T's Restaurant Tantanmen    Cup        Japan
# 3                         GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4                                       Singapore Curry  Pack        India
# 5                                Kimchi song Song Ramen  Pack  South Korea
# 6                   Spice Deli Tantan Men With Cilantro   Cup        Japan
# ...                                                 ...   ...          ...
# ...

# %%
(df.loc[st_col> st_col.mean()])
# Out:
#       Review #            Brand                              Variety Style  \
# 0         2580        New Touch            T's Restaurant Tantanmen    Cup
# 4         2576   Ching's Secret                      Singapore Curry  Pack
# 5         2575    Samyang Foods               Kimchi song Song Ramen  Pack
# 6         2574          Acecook  Spice Deli Tantan Men With Cilantro   Cup
# 7         2573      Ikeda Shoku                Nabeyaki Kitsune Udon  Tray
# ...        ...              ...                                  ...   ...
# 2557        23           Nissin             Top Ramen Creamy Chicken  Pack
# 2558        22         Nongshim           Ansungtangmyun Noodle Soup  Pack
# 2559        21         Nongshim            Champong Oriental Noodles  Pack
# 2561        19         Nongshim                          Shin Ramyun  Pack
# 2567        13  Sapporo Ichiban                            Chow Mein  Pack
#
#           Country Stars  Top Ten
# 0           Japan  3.75      NaN
# ...

# %%
print(f"Num of Unrated Rows : ",(df.Stars=='Unrated').sum())
df[df.Stars=='Unrated']
# Out:
# Num of Unrated Rows :  3
#      Review #          Brand                                Variety Style  \
# 32       2548         Ottogi  Plain Instant Noodle No Soup Included  Pack
# 122      2458  Samyang Foods                             Sari Ramen  Pack
# 993      1587       Mi E-Zee                          Plain Noodles  Pack
#
#          Country    Stars Top Ten
# 32   South Korea  Unrated     NaN
# 122  South Korea  Unrated     NaN
# 993     Malaysia  Unrated     NaN

# %% [markdown]
# Diches in taiwan and above rating avarage

# %%
df.loc[(df.Country =='Taiwan') & (st_col> 2.5),:]
# Out:
#       Review #             Brand  \
# 3         2577           Wei Lih
# 40        2540           Wei Lih
# 65        2515     Uni-President
# 68        2512  Mom's Dry Noodle
# 79        2501        Happy Cook
# ...        ...               ...
# 2499        81     Unif / Tung-I
# 2500        80     Unif / Tung-I
# 2512        68           Wei Lih
# 2522        58           Ve Wong
# 2572         8            Tung-I
#
#                                                 Variety Style Country Stars  \
# 3                         GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 40        GGE Noodle Snack Wheat Crackers Mexican Spicy  Pack  Taiwan  3.25
# 65      Man Han Feast Spicy Beef Flavor Instant Noodles  Bowl  Taiwan     5
# 68                                       Dan Dan Noodle  Pack  Taiwan     5
# 79                                   Toona Paste Noodle  Pack  Taiwan     4
# ...                                                 ...   ...     ...   ...
# ...

# %%
df.loc[(df.Country =='Taiwan') & (st_col> 2.5),['Brand','Style']]
# Out:
#                  Brand Style
# 3              Wei Lih  Pack
# 40             Wei Lih  Pack
# 65       Uni-President  Bowl
# 68    Mom's Dry Noodle  Pack
# 79          Happy Cook  Pack
# ...                ...   ...
# 2499     Unif / Tung-I  Pack
# 2500     Unif / Tung-I  Pack
# 2512           Wei Lih  Pack
# 2522           Ve Wong  Pack
# 2572            Tung-I  Pack
#
# [191 rows x 2 columns]

# %%
df.loc[(df.Country =='Taiwan') | (df.Country =='USA')]
# Out:
#       Review #     Brand                                            Variety  \
# 1         2579  Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2         2578    Nissin                      Cup Noodles Chicken Vegetable
# 3         2577   Wei Lih                      GGE Ramen Snack Tomato Flavor
# 11        2569  Yamachan                            Yokohama Tonkotsu Shoyu
# 17        2563  Yamachan                                  Tokyo Shoyu Ramen
# ...        ...       ...                                                ...
# 2546        34  Maruchan                           Ramen Noodle Soup Shrimp
# 2557        23    Nissin                           Top Ramen Creamy Chicken
# 2570        10     Smack                                     Vegetable Beef
# 2572         8    Tung-I                   Chinese Beef Instant Rice Noodle
# 2579         1  Westbrae                                         Miso Ramen
#
#      Style Country Stars Top Ten
# ...

# %%
df[df.Country.isin(['Taiwan','USA'])]
# Out:
#       Review #     Brand                                            Variety  \
# 1         2579  Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2         2578    Nissin                      Cup Noodles Chicken Vegetable
# 3         2577   Wei Lih                      GGE Ramen Snack Tomato Flavor
# 11        2569  Yamachan                            Yokohama Tonkotsu Shoyu
# 17        2563  Yamachan                                  Tokyo Shoyu Ramen
# ...        ...       ...                                                ...
# 2546        34  Maruchan                           Ramen Noodle Soup Shrimp
# 2557        23    Nissin                           Top Ramen Creamy Chicken
# 2570        10     Smack                                     Vegetable Beef
# 2572         8    Tung-I                   Chinese Beef Instant Rice Noodle
# 2579         1  Westbrae                                         Miso Ramen
#
#      Style Country Stars Top Ten
# ...

# %%
df_test=df
df_test.loc[df_test.Country=='Taiwan','Country']='Taiwanese'
df_test.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style    Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup      Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwanese     1
# 2                      Cup Noodles Chicken Vegetable   Cup        USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwanese  2.75
# 4                                    Singapore Curry  Pack      India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
