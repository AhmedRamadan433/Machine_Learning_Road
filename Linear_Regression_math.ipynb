# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedRamadan433/Machine_Learning_Road/blob/main/Linear_Regression_math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
x = np.linspace(0, 100, 100)
y = 5 * x - 12
ry = np.random.normal(scale=88,size=y.shape[0]) + y
# Initilize a DataFrame for the data
data = pd.DataFrame({'x': x, 'y':ry}).sample(frac=1).reset_index()[['x', 'y']]
plt.plot(x, ry, 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.plot(x, ry, 'o')
plt.plot(x, y, 'r-')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
data
# Out:
#             x           y
# 0   19.191919    8.799171
# 1    6.060606  101.910811
# 2   45.454545  176.722189
# 3   57.575758  302.496315
# 4   22.222222  175.181497
# ..        ...         ...
# 95  13.131313   64.363967
# 96  31.313131  177.843958
# 97  85.858586  584.131177
# 98  70.707071  405.695323
# 99  32.323232   71.491016
#
# [100 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# Fnd Line With Math

# %% [markdown]
# * Initialize Weights

# %% [markdown]
# * Compute Gradiant

# %%
x=x/x.max()

# %%
w1 = 0.0
w0 = 0.0
n = 100000
alpha = 0.01

for i in range(n):
    loss = np.mean((w1 * x + w0 - y) ** 2)
    if(i%100==0):
       print(f"Loss in iteration {i} = {loss}")
    dj_dw1 = np.mean((w1 * x + w0 - y) * x)
    dj_dw0 = np.mean(w1 * x + w0 - y)

    w1 = w1 - alpha * dj_dw1
    w0 = w0 - alpha * dj_dw0

print(f"\nFinal weights: w1 = {w1}, w0 = {w0}")
# Out:
# Loss in iteration 0 = 77898.20875420877
# Loss in iteration 100 = 16710.70075381174
# Loss in iteration 200 = 10607.460559093612
# Loss in iteration 300 = 8963.759768000093
# Loss in iteration 400 = 7814.167771354588
# Loss in iteration 500 = 6831.312137736946
# Loss in iteration 600 = 5973.587394750943
# Loss in iteration 700 = 5223.674286077347
# Loss in iteration 800 = 4567.913042480447
# Loss in iteration 900 = 3994.4744157916302
# Loss in iteration 1000 = 3493.023173616226
# Loss in iteration 1100 = 3054.5222321345154
# Loss in iteration 1200 = 2671.069043645677
# Loss in iteration 1300 = 2335.7531207153424
# Loss in iteration 1400 = 2042.5314927428863
# Loss in iteration 1500 = 1786.1198008671272
# Loss in iteration 1600 = 1561.8970646888504
# Loss in iteration 1700 = 1365.822404241479
# Loss in iteration 1800 = 1194.3622163728178
# Loss in iteration 1900 = 1044.426493129031
# Loss in iteration 2000 = 913.3131344882605
# Loss in iteration 2100 = 798.6592518634247
# ...

# %% [markdown]
# ---
#
# PLot line

# %%
plt.plot(x, ry, 'bx')
plt.plot(x, w1*x+w0, 'r')
